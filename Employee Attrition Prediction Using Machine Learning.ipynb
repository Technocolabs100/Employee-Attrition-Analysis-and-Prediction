# %% [markdown]
# # Data Exploration

# %% [markdown]
# import pandas as pd
#
# pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel(r"C:\Users\DELL\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.xlsx")

df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df = df.drop(columns="Over18")
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Data Labelling

# %%
from sklearn.preprocessing import LabelEncoder

columns_to_encode = ["BusinessTravel", "Department", "EducationField", "Gender", "JobRole", "MaritalStatus", "OverTime"]

label_encoder = LabelEncoder()

for column in columns_to_encode:
    df[column + '_encoded'] = label_encoder.fit_transform(df[column])

df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder

columns_to_encode = ["BusinessTravel", "Department", "EducationField", "Gender", "JobRole", "MaritalStatus", "OverTime" ]

label_encoders = {}

for column in columns_to_encode:
    label_encoders[column] = LabelEncoder()

    df[column] = label_encoders[column].fit_transform(df[column])

df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# # Machine Learning

# %%
pip install xgboost

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report,roc_auc_score,roc_curve,auc,mean_absolute_error

# %%
x = df.drop(['Attrition'], axis = 1)
y = df['Attrition']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,stratify = y, random_state=21)

# %%
rf = RandomForestClassifier()
svc = SVC()
knn = KNeighborsClassifier()
xgb = XGBClassifier()
nb = MultinomialNB()
lr = LogisticRegression()

# %% [markdown]
# # Predictive Modeling

# %%
rf.fit(x_train,y_train)
predict = rf.predict(x_test)
y_prob = rf.predict_proba(x_test)[:,1]
print(classification_report(y_test, predict))
ConfusionMatrixDisplay(confusion_matrix(y_test,predict)).plot()
print('mean absolute error:', mean_absolute_error(y_test,predict))
rf_score = accuracy_score(y_test, predict)
print('Accuracy:', rf_score)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_rf = auc(fpr, tpr)
print('AUC:', roc_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       370
#            1       0.75      0.13      0.22        71
#
#     accuracy                           0.85       441
#    macro avg       0.80      0.56      0.57       441
# weighted avg       0.84      0.85      0.81       441
#
# mean absolute error: 0.1473922902494331
# Accuracy: 0.8526077097505669
# AUC: 0.7881233346022077

# %% [markdown]
# # Exporting Prediction to a CSV File

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report,roc_auc_score,roc_curve,auc,mean_absolute_error


cm = confusion_matrix(y_test,predict)

cmdf = pd.DataFrame(cm, index=["Actual Negative", "Actual Positive"])

cmdf.to_csv(r'C:\Users\DELL\Documents\Python Webscraping Project\confusion_matrix.csv', index = False)
